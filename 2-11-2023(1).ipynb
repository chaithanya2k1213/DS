# %%
import seaborn as sns
import pandas as pd
import matplotlib as plt

# %%
f=pd.read_csv('flights satya.csv')
f.tail()
# Out:
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %%
a=set(f['year'])
a
# Out:
# {1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960}

# %%
sns.displot(data=f,x=f['year'], y=f['passengers'],)

# %%
sns.jointplot(x='year',y='passengers',data=f,ratio=5)

# %%
sns.pairplot(f,hue='passengers')

# %%
sns.rugplot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='year',y='passengers',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.countplot(x='year',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.boxplot(x='year',y='passengers',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.violinplot(x='year',y='passengers',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.stripplot(x='year',y='passengers',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.swarmplot(x='year',y='passengers',data=f,color='black',size=3)
sns.violinplot(x='year',y='passengers',data=f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>
