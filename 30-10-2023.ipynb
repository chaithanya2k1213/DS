# %% [markdown]
# ### Graph of Inner Graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.randint(1,10,5)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.3,0.3,0.4,0.4])

axes1.plot(x,y)
axes1.set_title('Larger Plot')

axes2.plot(y,x)
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %% [markdown]
# ### Subplots

# %%
fig=plt.figure()
fig,axes=plt.subplots(2,3)

plt.subplot(2,3,1)
plt.plot(x,y,'r*')

plt.subplot(2,3,2)
plt.plot(y,x,'y-')

plt.subplot(2,3,4)
plt.plot(x,y,'c-')

# %% [markdown]
# ### Maximum Properties in a graph

# %%
fig=plt.figure()
a=fig.add_axes([0,0,1,1])
a.plot(x,y,'g',lw=1,ls='-',marker='o',markersize=20,markerfacecolor='y',markeredgewidth=2, markeredgecolor='c')

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
labels=['a','b','c','d']
dataset=[1,2,3,4]
pd.Series(dataset)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(data=dataset,index=labels)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
dict_1={'a':10,'s':'20','d':30,'f':40}
pd.Series(dict_1)
# Out:
# a    10
# s    20
# d    30
# f    40
# dtype: object

# %%
a=np.random.randint(1,10,(5,4))
a
idx=['q','w','e','r','t']
colnames=['p','o','i','u']

# %%
df=pd.DataFrame(a,index=idx,columns=colnames)
df
# Out:
#    p  o  i  u
# q  9  2  4  7
# w  5  5  4  6
# e  1  7  5  2
# r  6  2  4  3
# t  9  9  6  4
